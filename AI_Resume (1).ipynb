# %%
# !pip install -q google-genai python-docx PyPDF2 python-dotenv pandas
# Out:
# [notice] A new release of pip is available: 26.1.2 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from google import genai
import PyPDF2
from docx import Document
import json
import pandas as pd

# %%
API_KEY = "AQ.Ab8RN6Lv6x2YCYEA0qDBLlX6ePHu2S5ZjmzHi9DztdD79cyg1g"

client = genai.Client(api_key=API_KEY)

print("✅ Gemini Connected Successfully!")
# Out:
# ✅ Gemini Connected Successfully!

# %%
def read_pdf(file_path):

    text=""

    reader=PyPDF2.PdfReader(file_path)

    for page in reader.pages:

        if page.extract_text():

            text+=page.extract_text()

    return text

# %%
def read_docx(file_path):

    doc=Document(file_path)

    text=[]

    for para in doc.paragraphs:

        text.append(para.text)

    return "\n".join(text)

# %%
resume_path=r"C:\Users\Ayush\Downloads\Ayush_Uniyal_Resume_DS_pdf.pdf"

# %%
if resume_path.endswith(".pdf"):

    resume_text=read_pdf(resume_path)

else:

    resume_text=read_docx(resume_path)

print(resume_text[:3000])
# Out:
# AYUSH UNIYAL
# Data Analyst | Data Scientist
# 9311894396  |  ayushworkspace26@gmail.com  |  linkedin.com/in/ayush-uniyal-5a7092291  |  Delhi, India
# CAREER SUMMARY
# Final-year Bachelor of Technology (B.Tech) student in Electronics & Communication Engineering (Expected 2027) with hands-on
# experience as a Python Developer Intern at CSIR-NPL (07/2025 – 08/2025), where I built data extraction and logging pipelines and
# maintained structured reports for the research team. Skilled across the full data analysis workflow: collecting, cleaning, and
# organizing raw data; performing exploratory data analysis and feature engineering; and building business-facing visualizations and
# insight reports — demonstrated through an end-to-end retail sales analysis project. Comfortable with Excel (formulas, pivot tables),
# SQL, Tableau, and Python, with growing exposure to machine learning tools including TensorFlow. Actively seeking a Data Analyst or
# ...

# %%
resume_text
# Out:
# "AYUSH UNIYAL\nData Analyst | Data Scientist\n9311894396  |  ayushworkspace26@gmail.com  |  linkedin.com/in/ayush-uniyal-5a7092291  |  Delhi, India\nCAREER SUMMARY\nFinal-year Bachelor of Technology (B.Tech) student in Electronics & Communication Engineering (Expected 2027) with hands-on \nexperience as a Python Developer Intern at CSIR-NPL (07/2025 – 08/2025), where I built data extraction and logging pipelines and \nmaintained structured reports for the research team. Skilled across the full data analysis workflow: collecting, cleaning, and \norganizing raw data; performing exploratory data analysis and feature engineering; and building business-facing visualizations and \ninsight reports — demonstrated through an end-to-end retail sales analysis project. Comfortable with Excel (formulas, pivot tables), \nSQL, Tableau, and Python, with growing exposure to machine learning tools including TensorFlow. Actively seeking a Data Analyst or \nData Scientist role, open to internships and f
# ...

# %%
prompt=f"""
You are an AI Resume Screening Assistant.

Analyze the resume carefully.

Return the following information.

Candidate Name

Technical Skills

Soft Skills

Education

Experience

Profile Summary

Recommended Job Role

Missing Skills

ATS Score out of 100

Resume

{resume_text}
"""

# %%
response = client.models.generate_content(
    model="gemini-2.0-flash-lite",
    contents=prompt
)

print(response.text)
# Out:
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 response = client.models.generate_content(
#       2     model="gemini-2.0-flash-lite",
#       3     contents=prompt
#       4 )
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\google\genai\models.py:6604, in Models.generate_content(self, model, contents, config)
#    6598   parsed_config_to_call = _extra_utils.get_usage_header(
#    6599       parsed_config_to_call,
#    6600       types.GenerateContentConfig,
#    6601       'afc',
#    6602   )
#    6603 i += 1
# -> 6604 response = self._generate_content(
#    6605     model=model, contents=contents, config=parsed_config_to_call
#    6606 )
#    6608 if not function_map:
#    6609   break
#
# ...
